# %%
from cfr.pkr.abstraction.game import _default_bucketer

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.arange(1, 400)
y = [_default_bucketer(pot) for pot in x]
plt.plot(x, y)
